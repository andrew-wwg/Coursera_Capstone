# %%
import requests
import pandas as pd
pd.set_option("display.max_rows", 20, "display.max_columns", 20)
import numpy as np # library to handle data in a vectorized manner
import matplotlib.cm as cm
import matplotlib.colors as colors
import random # library for random number generation
import json # library to handle JSON files
import urllib
#The following packages are useful but I did not use here
#!pip install beautifulsoup4
#from bs4 import BeautifulSoup
#!pip install lxml

# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# import k-means from clustering stage
from sklearn.cluster import KMeans

! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in c:\users\andrew\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\andrew\anaconda3\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: folium==0.5.0 in c:\users\andrew\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: requests in c:\users\andrew\anaconda3\lib\site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: jinja2 in c:\users\andrew\anaconda3\lib\site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: six in c:\users\andrew\anaconda3\lib\site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: branca in c:\users\andrew\anaconda3\lib\site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\andrew\anaconda3\lib\site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andrew\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\andrew\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\andrew\anaconda3\lib\site-packages (from requests->folium==0.5.0) (1.25.11)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\andrew\anaconda3\lib\site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Folium installed
# Libraries imported.

# %%
Val_df = pd.read_csv(r"C:\Users\Andrew\Downloads\ValenciaData.csv")
Val_df.head()
# Out:
#   PostCode Neighbourhood  NumberOfTaxpayers  MedianSalary
# 0    46001      El Pilar               5704         36408
# 1    46002     El Centro               2441         58533
# 2    46003        Carmen               5926         42229
# 3    46004  Pla de Remei               4917         72577
# 4    46005      Gran Vía              10831          4643

# %%
Spain_json=result['results']

# %%
# define the dataframe columns
column_names = ['PostCode', 'PlaceName', 'Latitude', 'Longitude'] 

# instantiate the dataframe
Spain_df = pd.DataFrame(columns=column_names)
Spain_df
# Out:
# Empty DataFrame
# Columns: [PostCode, PlaceName, Latitude, Longitude]
# Index: []

# %%
for data in Spain_json:
    codigopostal = data['Postal_Code']
    zona = data['Place_Name']
    lat = data['Latitude']
    long = data['Longitude']

    Spain_df = Spain_df.append({'PostCode': codigopostal,
                                          'PlaceName': zona,
                                          'Latitude': lat,
                                          'Longitude': long}, ignore_index=True)
print(Spain_df)
# Out:
#     PostCode         PlaceName  Latitude  Longitude
# 0       4080           Almeria   36.8381    -2.4597
# 1       4001           Almeria   36.8381    -2.4597
# 2       4009           Almeria   36.8381    -2.4597
# 3       4114         Tristanes   36.9740    -2.1469
# 4       4116         Hornillos   36.8802    -2.0047
# ..       ...               ...       ...        ...
# 495     4113         Atochares   36.8825    -2.1058
# 496     4149  El Saltador Alto   37.0051    -1.9311
# 497     4116        Las Negras   36.8802    -2.0047
# 498     4114   Torre Del Campo   36.9877    -2.1075
# 499     4149  Gafares (Sorbas)   37.0051    -1.9311
#
# [500 rows x 4 columns]

# %%
df1=Val_df.merge(Spain_df, on='PostCode', how='left')
df1
# Out:
#    PostCode               Neighbourhood  NumberOfTaxpayers  MedianSalary  \
# 0     46001                    El Pilar               5704         36408
# 1     46002                   El Centro               2441         58533
# 2     46003                      Carmen               5926         42229
# 3     46004                Pla de Remei               4917         72577
# 4     46005                    Gran Vía              10831          4643
# ..      ...                         ...                ...           ...
# 24    46025                   Benicalap              16594         23547
# 25    46026                     Malilla              10673         24416
# 26    46035          Sant Pau-Benimanet               5541         21543
# 27    46112  Massarrochos-Santa Bárbara               1201         43296
# 28    Resto                       Resto              16718         27457
#
#    PlaceName  Latitude  Longitude
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4        NaN       NaN        NaN
# ..       ...       ...        ...
# 24       NaN       NaN        NaN
# 25       NaN       NaN        NaN
# 26       NaN       NaN        NaN
# 27       NaN       NaN        NaN
# 28       NaN       NaN        NaN
#
# [29 rows x 7 columns]

# %%
#adding a condition to filter out the majority of unneccessary data for elsewhere in Spain
where = urllib.parse.quote_plus("""
{
    "Postal_Code": {
        "$gt": 45999
    }
}
""")
url = 'https://parseapi.back4app.com/classes/Spainpostalcode_Spain_Postal_Code?limit=50&order=Postal_Code&keys=Place_Name,Postal_Code,Longitude,Latitude&where=%s' % where
headers = {
    'X-Parse-Application-Id': 'L1J6TLuzAJOD0PTSbaxxAL6MumtHfwkyr2Fg41Xq', # This is your app's application id
    'X-Parse-REST-API-Key': '0W3mihPdwBy2bud7Tj7fSS4CLR223AX1Qii5zZYd' # This is your app's REST API key
}
rawdata = json.loads(requests.get(url, headers=headers).content.decode('utf-8')) # Here you have the data that you need
print(rawdata)
# Out:
# {'results': [{'objectId': 'oKdBLFNCuv', 'Postal_Code': 46001, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.765Z', 'updatedAt': '2020-02-19T19:53:04.765Z'}, {'objectId': '95PvphOe7f', 'Postal_Code': 46002, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.765Z', 'updatedAt': '2020-02-19T19:53:04.765Z'}, {'objectId': 'nG9Su0yyvN', 'Postal_Code': 46003, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.765Z', 'updatedAt': '2020-02-19T19:53:04.765Z'}, {'objectId': 'EBCkLudIje', 'Postal_Code': 46004, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.765Z', 'updatedAt': '2020-02-19T19:53:04.765Z'}, {'objectId': 'O9ijjNCgzw', 'Postal_Code': 46005, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.765Z', 'updatedAt': '2020-02-19T19:53:04.765Z'}, {'objectId': 'o6IffN2t51', 'Postal_Code': 46006, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.765Z', 'updatedAt': '2020-02-19T19:53:04.765Z'}, {'objectId': 'dvoylFOhw2', 'Postal_Code': 46007, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.765Z', 'updatedAt': '2020-02-19T19:53:04.765Z'}, {'objectId': 'HqUwOS3tDx', 'Postal_Code': 46008, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.765Z', 'updatedAt': '2020-02-19T19:53:04.765Z'}, {'objectId': 'tGlSL6qKQv', 'Postal_Code': 46009, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.765Z', 'updatedAt': '2020-02-19T19:53:04.765Z'}, {'objectId': '4dn7bq2Rn0', 'Postal_Code': 46010, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.970Z', 'updatedAt': '2020-02-19T19:53:04.970Z'}, {'objectId': 'lVZKuxhJyq', 'Postal_Code': 46011, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.970Z', 'updatedAt': '2020-02-19T19:53:04.970Z'}, {'objectId': 'IbERJiNBIr', 'Postal_Code': 46012, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.970Z', 'updatedAt': '2020-02-19T19:53:04.970Z'}, {'objectId': 'yRWFygvuyt', 'Postal_Code': 46013, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.970Z', 'updatedAt': '2020-02-19T19:53:04.970Z'}, {'objectId': 'j4uMMXvqc6', 'Postal_Code': 46014, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.970Z', 'updatedAt': '2020-02-19T19:53:04.970Z'}, {'objectId': 'eKXsT9pvFr', 'Postal_Code': 46015, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.970Z', 'updatedAt': '2020-02-19T19:53:04.970Z'}, {'objectId': '5EFv6HFtRz', 'Postal_Code': 46016, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.970Z', 'updatedAt': '2020-02-19T19:53:04.970Z'}, {'objectId': 'aT0hCOXLaz', 'Postal_Code': 46017, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.971Z', 'updatedAt': '2020-02-19T19:53:04.971Z'}, {'objectId': 'F6KBQNsEVC', 'Postal_Code': 46018, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.971Z', 'updatedAt': '2020-02-19T19:53:04.971Z'}, {'objectId': 'IeNvy9JGHK', 'Postal_Code': 46019, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.971Z', 'updatedAt': '2020-02-19T19:53:04.971Z'}, {'objectId': 'ARoby2Qb9o', 'Postal_Code': 46020, 'Place_Name': 'Valencia', 'Latitude': 39.4698, 'Longitude': -0.3774, 'createdAt': '2020-02-19T19:53:04.971Z', 'updatedA ...

# %%
#improve the clarity of the output
Spain_data_json=rawdata['results']
Spain_data_json
# Out:
# [{'objectId': 'oKdBLFNCuv',
#   'Postal_Code': 46001,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.765Z',
#   'updatedAt': '2020-02-19T19:53:04.765Z'},
#  {'objectId': '95PvphOe7f',
#   'Postal_Code': 46002,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.765Z',
#   'updatedAt': '2020-02-19T19:53:04.765Z'},
#  {'objectId': 'nG9Su0yyvN',
#   'Postal_Code': 46003,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.765Z',
#   'updatedAt': '2020-02-19T19:53:04.765Z'},
#  {'objectId': 'EBCkLudIje',
#   'Postal_Code': 46004,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.765Z',
#   'updatedAt': '2020-02-19T19:53:04.765Z'},
#  {'objectId': 'O9ijjNCgzw',
#   'Postal_Code': 46005,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.765Z',
#   'updatedAt': '2020-02-19T19:53:04.765Z'},
#  {'objectId': 'o6IffN2t51',
#   'Postal_Code': 46006,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.765Z',
#   'updatedAt': '2020-02-19T19:53:04.765Z'},
#  {'objectId': 'dvoylFOhw2',
#   'Postal_Code': 46007,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.765Z',
#   'updatedAt': '2020-02-19T19:53:04.765Z'},
#  {'objectId': 'HqUwOS3tDx',
#   'Postal_Code': 46008,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.765Z',
#   'updatedAt': '2020-02-19T19:53:04.765Z'},
#  {'objectId': 'tGlSL6qKQv',
#   'Postal_Code': 46009,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.765Z',
#   'updatedAt': '2020-02-19T19:53:04.765Z'},
#  {'objectId': '4dn7bq2Rn0',
#   'Postal_Code': 46010,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.970Z',
#   'updatedAt': '2020-02-19T19:53:04.970Z'},
#  {'objectId': 'lVZKuxhJyq',
#   'Postal_Code': 46011,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.970Z',
#   'updatedAt': '2020-02-19T19:53:04.970Z'},
#  {'objectId': 'IbERJiNBIr',
#   'Postal_Code': 46012,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.970Z',
#   'updatedAt': '2020-02-19T19:53:04.970Z'},
#  {'objectId': 'yRWFygvuyt',
#   'Postal_Code': 46013,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.970Z',
#   'updatedAt': '2020-02-19T19:53:04.970Z'},
#  {'objectId': 'j4uMMXvqc6',
#   'Postal_Code': 46014,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.970Z',
#   'updatedAt': '2020-02-19T19:53:04.970Z'},
#  {'objectId': 'eKXsT9pvFr',
#   'Postal_Code': 46015,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.970Z',
#   'updatedAt': '2020-02-19T19:53:04.970Z'},
#  {'objectId': '5EFv6HFtRz',
#   'Postal_Code': 46016,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.970Z',
#   'updatedAt': '2020-02-19T19:53:04.970Z'},
#  {'objectId': 'aT0hCOXLaz',
#   'Postal_Code': 46017,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'F6KBQNsEVC',
#   'Postal_Code': 46018,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'IeNvy9JGHK',
#   'Postal_Code': 46019,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'ARoby2Qb9o',
#   'Postal_Code': 46020,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'F5P5KxNAFz',
#   'Postal_Code': 46021,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'mzh39Zmaif',
#   'Postal_Code': 46022,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'leCL0YdrPj',
#   'Postal_Code': 46023,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'LkMGsJGUP8',
#   'Postal_Code': 46024,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'GLSlB6eNIp',
#   'Postal_Code': 46025,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'JLcTApVWBU',
#   'Postal_Code': 46026,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'mwGWx0nSCE',
#   'Postal_Code': 46035,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.5,
#   'Longitude': -0.4167,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'VA8ldPlMX8',
#   'Postal_Code': 46035,
#   'Place_Name': 'Benimamet',
#   'Latitude': 39.5,
#   'Longitude': -0.4167,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'f9zhXwRSGY',
#   'Postal_Code': 46070,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'edvmdtyIG2',
#   'Postal_Code': 46071,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'ItUxBt2bYe',
#   'Postal_Code': 46080,
#   'Place_Name': 'Valencia',
#   'Latitude': 39.4698,
#   'Longitude': -0.3774,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'Cu6ukfmlNU',
#   'Postal_Code': 46100,
#   'Place_Name': 'Burjassot',
#   'Latitude': 39.5167,
#   'Longitude': -0.4167,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'MWgr1fPjNx',
#   'Postal_Code': 46110,
#   'Place_Name': 'Godella',
#   'Latitude': 39.5333,
#   'Longitude': -0.4167,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'QBwaPuW6Ze',
#   'Postal_Code': 46110,
#   'Place_Name': 'Campo Olivar',
#   'Latitude': 39.5333,
#   'Longitude': -0.4167,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'CIlrxbxmSX',
#   'Postal_Code': 46111,
#   'Place_Name': 'Santa Barbara (Urbanitzacio)',
#   'Latitude': 39.5333,
#   'Longitude': -0.4,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'Opp6fDUDg2',
#   'Postal_Code': 46111,
#   'Place_Name': 'Rocafort',
#   'Latitude': 39.5333,
#   'Longitude': -0.4,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'uK8uXWXmcD',
#   'Postal_Code': 46112,
#   'Place_Name': 'Masarrochos',
#   'Latitude': 39.5333,
#   'Longitude': -0.4,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'T7d0eZJrv1',
#   'Postal_Code': 46113,
#   'Place_Name': 'Moncada',
#   'Latitude': 39.5456,
#   'Longitude': -0.3955,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': '799X2C3do9',
#   'Postal_Code': 46114,
#   'Place_Name': 'Vinalesa',
#   'Latitude': 39.5333,
#   'Longitude': -0.3667,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'gxVR9kTmoB',
#   'Postal_Code': 46115,
#   'Place_Name': 'Alfara Del Patriarca',
#   'Latitude': 39.55,
#   'Longitude': -0.3833,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'VL8jqgLIOO',
#   'Postal_Code': 46116,
#   'Place_Name': 'Masias',
#   'Latitude': 39.5729,
#   'Longitude': -0.4112,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'I9jUvar3df',
#   'Postal_Code': 46116,
#   'Place_Name': 'San Isidro De Benageber',
#   'Latitude': 39.5729,
#   'Longitude': -0.4112,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'Fopcv7gWXs',
#   'Postal_Code': 46117,
#   'Place_Name': 'Vall De Flors (Urbanitzacio)',
#   'Latitude': 39.5833,
#   'Longitude': -0.45,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'TK8oLF8nCX',
#   'Postal_Code': 46117,
#   'Place_Name': 'Benagolf (Betera) (Urbanizacion)',
#   'Latitude': 39.5833,
#   'Longitude': -0.45,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': '7tNNLlO7gI',
#   'Postal_Code': 46117,
#   'Place_Name': 'Betera',
#   'Latitude': 39.5833,
#   'Longitude': -0.45,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'OyaeFheQde',
#   'Postal_Code': 46117,
#   'Place_Name': 'Benagolf (San Antonio) (Urbanizacion)',
#   'Latitude': 39.5833,
#   'Longitude': -0.45,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'PeG0qegZ3N',
#   'Postal_Code': 46118,
#   'Place_Name': 'Porta Coeli',
#   'Latitude': 39.6833,
#   'Longitude': -0.4333,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'eFehQgJGEC',
#   'Postal_Code': 46118,
#   'Place_Name': 'Serra',
#   'Latitude': 39.6833,
#   'Longitude': -0.4333,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'Fc1OlTbvve',
#   'Postal_Code': 46118,
#   'Place_Name': 'Cartuja De Portaceli',
#   'Latitude': 39.6833,
#   'Longitude': -0.4333,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'},
#  {'objectId': 'AGNM70i6oj',
#   'Postal_Code': 46119,
#   'Place_Name': 'Naquera',
#   'Latitude': 39.65,
#   'Longitude': -0.4167,
#   'createdAt': '2020-02-19T19:53:04.971Z',
#   'updatedAt': '2020-02-19T19:53:04.971Z'}]

# %%
#creating a new empty dataframe to put this data
# define the dataframe columns
column_names = ['PostCode', 'PlaceName', 'Latitude', 'Longitude'] 

# instantiate the dataframe
Spain_df = pd.DataFrame(columns=column_names)
Spain_df
# Out:
# Empty DataFrame
# Columns: [PostCode, PlaceName, Latitude, Longitude]
# Index: []

# %%
#populate the new dataframe

for data in Spain_data_json:
    codigopostal = data['Postal_Code']
    zona = data['Place_Name']
    lat = data['Latitude']
    long = data['Longitude']

    Spain_df = Spain_df.append({'PostCode': codigopostal,
                                          'PlaceName': zona,
                                          'Latitude': lat,
                                          'Longitude': long}, ignore_index=True)
Spain_df.head()
# Out:
#   PostCode PlaceName  Latitude  Longitude
# 0    46001  Valencia   39.4698    -0.3774
# 1    46002  Valencia   39.4698    -0.3774
# 2    46003  Valencia   39.4698    -0.3774
# 3    46004  Valencia   39.4698    -0.3774
# 4    46005  Valencia   39.4698    -0.3774

# %%
#Verify that dataframes contain the same datatype to enable merging
Spain_df['PostCode']=Spain_df['PostCode'].astype(str)
Val_df['PostCode']=Val_df['PostCode'].astype(str)
# Out:
# PostCode      object
# PlaceName     object
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
#merging
df1=Val_df.merge(Spain_df, on='PostCode', how='left')
df1
# Out:
#    PostCode               Neighbourhood  NumberOfTaxpayers  MedianSalary  \
# 0     46001                    El Pilar               5704         36408
# 1     46002                   El Centro               2441         58533
# 2     46003                      Carmen               5926         42229
# 3     46004                Pla de Remei               4917         72577
# 4     46005                    Gran Vía              10831          4643
# ..      ...                         ...                ...           ...
# 25    46026                     Malilla              10673         24416
# 26    46035          Sant Pau-Benimanet               5541         21543
# 27    46035          Sant Pau-Benimanet               5541         21543
# 28    46112  Massarrochos-Santa Bárbara               1201         43296
# 29    Resto                       Resto              16718         27457
#
#       PlaceName  Latitude  Longitude
# 0      Valencia   39.4698    -0.3774
# 1      Valencia   39.4698    -0.3774
# 2      Valencia   39.4698    -0.3774
# 3      Valencia   39.4698    -0.3774
# 4      Valencia   39.4698    -0.3774
# ..          ...       ...        ...
# 25     Valencia   39.4698    -0.3774
# 26     Valencia   39.5000    -0.4167
# 27    Benimamet   39.5000    -0.4167
# 28  Masarrochos   39.5333    -0.4000
# 29          NaN       NaN        NaN
#
# [30 rows x 7 columns]

# %%
#remove NaN values
df1.dropna(subset = ['PlaceName'], inplace=True)
df1
# Out:
#    PostCode               Neighbourhood  NumberOfTaxpayers  MedianSalary  \
# 0     46001                    El Pilar               5704         36408
# 1     46002                   El Centro               2441         58533
# 2     46003                      Carmen               5926         42229
# 3     46004                Pla de Remei               4917         72577
# 4     46005                    Gran Vía              10831          4643
# ..      ...                         ...                ...           ...
# 24    46025                   Benicalap              16594         23547
# 25    46026                     Malilla              10673         24416
# 26    46035          Sant Pau-Benimanet               5541         21543
# 27    46035          Sant Pau-Benimanet               5541         21543
# 28    46112  Massarrochos-Santa Bárbara               1201         43296
#
#       PlaceName  Latitude  Longitude
# 0      Valencia   39.4698    -0.3774
# 1      Valencia   39.4698    -0.3774
# 2      Valencia   39.4698    -0.3774
# 3      Valencia   39.4698    -0.3774
# 4      Valencia   39.4698    -0.3774
# ..          ...       ...        ...
# 24     Valencia   39.4698    -0.3774
# 25     Valencia   39.4698    -0.3774
# 26     Valencia   39.5000    -0.4167
# 27    Benimamet   39.5000    -0.4167
# 28  Masarrochos   39.5333    -0.4000
#
# [29 rows x 7 columns]

# %%
# Out:
# 'Carmen'

# %%
for index,value in df1['Neighbourhood'].items():
    try:
        address=value+', Valencia, Spain'
        geolocator = Nominatim(user_agent="foursquare_agent")
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        df1['Latitude'][index]=latitude
        df1['Longitude'][index]=longitude
    except:
        pass
df1
# Out:
# <ipython-input-80-200d5d75423f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Latitude'][index]=latitude
# <ipython-input-80-200d5d75423f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Longitude'][index]=longitude
#    PostCode               Neighbourhood  NumberOfTaxpayers  MedianSalary  \
# 0     46001                    El Pilar               5704         36408
# 1     46002                   El Centro               2441         58533
# 2     46003                      Carmen               5926         42229
# 3     46004                Pla de Remei               4917         72577
# 4     46005                    Gran Vía              10831          4643
# ..      ...                         ...                ...           ...
# 24    46025                   Benicalap              16594         23547
# 25    46026                     Malilla              10673         24416
# 26    46035          Sant Pau-Benimanet               5541         21543
# 27    46035          Sant Pau-Benimanet               5541         21543
# 28    46112  Massarrochos-Santa Bárbara               1201         43296
#
#       PlaceName   Latitude  Longitude  Cluster
# 0      Valencia  38.389457  -0.509706        4
# 1      Valencia  38.109438  -0.791796        2
# 2      Valencia  39.478221  -0.381001        1
# 3      Valencia  39.469800  -0.377400        5
# 4      Valencia  39.465072  -0.365904        3
# ..          ...        ...        ...      ...
# 24     Valencia  39.494270  -0.391193        0
# 25     Valencia  39.449107  -0.375599        0
# 26     Valencia  39.500000  -0.416700        0
# 27    Benimamet  39.500000  -0.416700        0
# 28  Masarrochos  39.533300  -0.400000        1
#
# [29 rows x 8 columns]

# %%
for index, row in df1.iterrows():
    try:
        address = df1['Neighbourhood'][index] + ", ES"
        geolocator = Nominatim(user_agent="foursquare_agent")
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        df1['Latitude'][i]=latitude
        df1['Longitude'][i]=longitude
    except AttributeError:
        pass
df1
# Out:
# <ipython-input-52-89104213c459>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Latitude'][i]=latitude
# <ipython-input-52-89104213c459>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Longitude'][i]=longitude
#    PostCode               Neighbourhood  NumberOfTaxpayers  MedianSalary  \
# 0     46001                    El Pilar               5704         36408
# 1     46002                   El Centro               2441         58533
# 2     46003                      Carmen               5926         42229
# 3     46004                Pla de Remei               4917         72577
# 4     46005                    Gran Vía              10831          4643
# ..      ...                         ...                ...           ...
# 24    46025                   Benicalap              16594         23547
# 25    46026                     Malilla              10673         24416
# 26    46035          Sant Pau-Benimanet               5541         21543
# 27    46035          Sant Pau-Benimanet               5541         21543
# 28    46112  Massarrochos-Santa Bárbara               1201         43296
#
#       PlaceName  Latitude  Longitude  Cluster
# 0      Valencia   39.4698    -0.3774        4
# 1      Valencia   39.4698    -0.3774        2
# 2      Valencia   39.4698    -0.3774        1
# 3      Valencia   39.4698    -0.3774        5
# 4      Valencia   39.4698    -0.3774        3
# ..          ...       ...        ...      ...
# 24     Valencia   39.4698    -0.3774        0
# 25     Valencia   39.4698    -0.3774        0
# 26     Valencia   39.5000    -0.4167        0
# 27    Benimamet   39.5000    -0.4167        0
# 28  Masarrochos   39.5333    -0.4000        1
#
# [29 rows x 8 columns]

# %%
#Create a clustering based on coordinates and median salary
kclusters=6
val_clustering = df1.drop(['PostCode','Neighbourhood','NumberOfTaxpayers','PlaceName'],1)
val_clustering
# Out:
#     MedianSalary   Latitude  Longitude  Cluster
# 0          36408  38.389457  -0.509706        4
# 1          58533  38.109438  -0.791796        2
# 2          42229  39.478221  -0.381001        1
# 3          72577  39.469800  -0.377400        5
# 4           4643  39.465072  -0.365904        3
# ..           ...        ...        ...      ...
# 24         23547  39.494270  -0.391193        0
# 25         24416  39.449107  -0.375599        0
# 26         21543  39.500000  -0.416700        0
# 27         21543  39.500000  -0.416700        0
# 28         43296  39.533300  -0.400000        1
#
# [29 rows x 4 columns]

# %%
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(val_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 2, 1, 5, 3, 3, 4, 4, 0, 1])

# %%
#add cluster data to the main dataframe
df1.insert(8, 'Cluster2', kmeans.labels_)
df1
# Out:
#    PostCode               Neighbourhood  NumberOfTaxpayers  MedianSalary  \
# 0     46001                    El Pilar               5704         36408
# 1     46002                   El Centro               2441         58533
# 2     46003                      Carmen               5926         42229
# 3     46004                Pla de Remei               4917         72577
# 4     46005                    Gran Vía              10831          4643
# ..      ...                         ...                ...           ...
# 24    46025                   Benicalap              16594         23547
# 25    46026                     Malilla              10673         24416
# 26    46035          Sant Pau-Benimanet               5541         21543
# 27    46035          Sant Pau-Benimanet               5541         21543
# 28    46112  Massarrochos-Santa Bárbara               1201         43296
#
#       PlaceName   Latitude  Longitude  Cluster  Cluster2
# 0      Valencia  38.389457  -0.509706        4         4
# 1      Valencia  38.109438  -0.791796        2         2
# 2      Valencia  39.478221  -0.381001        1         1
# 3      Valencia  39.469800  -0.377400        5         5
# 4      Valencia  39.465072  -0.365904        3         3
# ..          ...        ...        ...      ...       ...
# 24     Valencia  39.494270  -0.391193        0         0
# 25     Valencia  39.449107  -0.375599        0         0
# 26     Valencia  39.500000  -0.416700        0         0
# 27    Benimamet  39.500000  -0.416700        0         0
# 28  Masarrochos  39.533300  -0.400000        1         1
#
# [29 rows x 9 columns]

# %%
#find address of Valencia in order to create correctly centred folium map
address = 'Valencia, ES'

geolocator = Nominatim(user_agent="tora_the_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Valencia are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Valencia are 39.4697065, -0.3763353.

# %%
#generate map to visualize the neighbourhoods
# create map
map_Valencia = folium.Map(location=[latitude, longitude], zoom_start=11)
kclusters=6
# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lng, neigh, medsal, cluster2 in zip(df1['Latitude'], df1['Longitude'], df1['Neighbourhood'], df1['MedianSalary'], df1['Cluster2']):
    label = folium.Popup(str(neigh) + ', Cluster ' + str(cluster2), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=10,
        popup=label,
        color=rainbow[cluster2-1],
        fill=True,
        fill_color=rainbow[cluster2-1],
        fill_opacity=0.7).add_to(map_Valencia)
       
map_Valencia
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_efb995ed71664b91a59691137a041f03%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_efb995ed71664b91a59691137a041f03%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_efb995ed71664b91a59691137a041f03%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_efb995ed71664b91a59691137a041f03%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B39.4697065%2C-0.3763353%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...

# %%
#sort dataframe by median salary in descending order
df2=df1.sort_values(by='Cluster2', ascending=False, na_position='first', inplace=False)
df2
# Out:
#    PostCode     Neighbourhood  NumberOfTaxpayers  MedianSalary PlaceName  \
# 3     46004      Pla de Remei               4917         72577  Valencia
# 0     46001          El Pilar               5704         36408  Valencia
# 7     46008         Extramurs              15422         34061  Valencia
# 22    46023  La Crus Del Grao              15513         38053  Valencia
# 20    46021           Algirós              17531         33191  Valencia
# ..      ...               ...                ...           ...       ...
# 16    46017  La Cruz Cubierto              20936         23407  Valencia
# 13    46014  Barrio de La Luz              19162         24447  Valencia
# 12    46013            Quatre                912         28765  Valencia
# 10    46011   Poblet Maritims              15335         25319  Valencia
# 18    46019         Torrefiel              17271         24659  Valencia
#
#      Latitude  Longitude  Cluster  Cluster2
# 3   39.469800  -0.377400        5         5
# 0   38.389457  -0.509706        4         4
# 7   39.467878  -0.384593        4         4
# 22  39.469800  -0.377400        4         4
# 20  39.476849  -0.344421        4         4
# ..        ...        ...      ...       ...
# 16  39.469800  -0.377400        0         0
# 13  39.467422  -0.415659        0         0
# 12  39.444516  -0.360099        0         0
# 10  39.469800  -0.377400        0         0
# 18  39.494648  -0.376130        0         0
#
# [29 rows x 9 columns]

# %%
CLIENT_ID = 'YEOIOK2UK5DZ2CUM4NQCTZBFJ124FL2TSJTPIJ0EBLDQL1JU' # your Foursquare ID
CLIENT_SECRET = 'FZOLLHQ5PGTLLVZ3DDJONQ2TQ1WDUMPRKNPF40LJOW30HEN4' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value
ACCESS_TOKEN = '20HBIOBQI4QJ4NAN11RRB2GGJUTNDW5VSEECRZOZXS5LK2YN'

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: YEOIOK2UK5DZ2CUM4NQCTZBFJ124FL2TSJTPIJ0EBLDQL1JU
# CLIENT_SECRET:FZOLLHQ5PGTLLVZ3DDJONQ2TQ1WDUMPRKNPF40LJOW30HEN4

# %%
address = 'Pla de Remei, ES'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 39.4680141 -0.3705643

# %%
search_query = 'bar'
radius = 500
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# bar .... OK!
# 'https://api.foursquare.com/v2/venues/search?client_id=YEOIOK2UK5DZ2CUM4NQCTZBFJ124FL2TSJTPIJ0EBLDQL1JU&client_secret=FZOLLHQ5PGTLLVZ3DDJONQ2TQ1WDUMPRKNPF40LJOW30HEN4&ll=39.4680141,-0.3705643&oauth_token=20HBIOBQI4QJ4NAN11RRB2GGJUTNDW5VSEECRZOZXS5LK2YN&v=20180605&query=bar&radius=500&limit=100'

# %%
results = requests.get(url).json()

venues = results['response']['venues']
PDR_venues = json_normalize(venues)

PDR_venues
# Out:
# <ipython-input-104-090ebc437e57>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   PDR_venues = json_normalize(venues)
#                           id                        name  \
# 0   4bd882155cf276b0416f9d00       Bar Ché Taberna vasca
# 1   4c1369e9a9c220a168b1559d              Bar Casa Mundo
# 2   4df2354d22718759f81aa628      Sportium en Bar Inglés
# 3   4e39376918a8d2fcc628dc91                    Bar Sena
# 4   4d84b0109324236afd4bbe0e                    Bar Rubi
# ..                       ...                         ...
# 45  5cff9d71f5e9d7002cb3d62e  El Timbre - Bar y Parrilla
# 46  4c267ee75c5ca593944b46fe           MALUKO Coffee Bar
# 47  56c5cac9cd10cf52a731d587        Tributo - Brasas Bar
# 48  4cd711de89eb6dcbac28331e                   Lowen Bar
# 49  4e6f3aba62e1d475e216b4c8                   Resto Bar
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d150941735', 'name': 'S...  v-1618948857    False
# 1   [{'id': '4bf58dd8d48988d1db931735', 'name': 'T...  v-1618948857    False
# 2   [{'id': '52f2ab2ebcbc57f1066b8b40', 'name': 'B...  v-1618948857    False
# 3   [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1618948857    False
# 4                                                  []  v-1618948857    False
# ..                                                ...           ...      ...
# 45  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1618948857    False
# 46  [{'id': '4bf58dd8d48988d1c7941735', 'name': 'S...  v-1618948857    False
# 47  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1618948857    False
# 48  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...  v-1618948857    False
# 49  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1618948857    False
#
#                  location.address    location.crossStreet  location.lat  \
# 0         Av. Regne de Valencia 9  Carrer Gregorio Mayans     39.464686
# 1          Don Juan de Austria 11            Dr. Romagosa     39.470394
# 2               C/ Conde Altea, 5                     NaN     39.465335
# 3      Calle General San Martin 2                     NaN     39.465434
# 4            Martinez Cubells, 10                     NaN     39.468003
# ..                            ...                     ...           ...
# 45  Plaça de Cánovas del Castillo                      12     39.468749
# 46                            NaN                     NaN     39.468446
# 47                      Ciscar 24                     NaN     39.466022
# 48            Carrer de Ciscar 25          Conde de altea     39.466104
# 49                            NaN                     NaN     39.468483
#
#     location.lng                            location.labeledLatLngs  \
# 0      -0.372123  [{'label': 'display', 'lat': 39.46468604825563...
# 1      -0.372505  [{'label': 'display', 'lat': 39.47039421597435...
# 2      -0.369937  [{'label': 'display', 'lat': 39.4653349379764,...
# 3      -0.375904  [{'label': 'display', 'lat': 39.46543412227221...
# 4      -0.373080  [{'label': 'display', 'lat': 39.468003, 'lng':...
# ..           ...                                                ...
# 45     -0.365919  [{'label': 'display', 'lat': 39.468749, 'lng':...
# 46     -0.375809  [{'label': 'display', 'lat': 39.468446, 'lng':...
# 47     -0.365903  [{'label': 'display', 'lat': 39.466022, 'lng':...
# 48     -0.365457  [{'label': 'display', 'lat': 39.46610355, 'lng...
# 49     -0.375808  [{'label': 'display', 'lat': 39.468483, 'lng':...
#
#     location.distance location.postalCode location.cc location.city  \
# 0                 393               46005          ES      Valencia
# 1                 313               46002          ES      Valencia
# 2                 303               46005          ES      Valencia
# 3                 541                 NaN          ES      Valencia
# 4                 216               46002          ES      Valencia
# ..                ...                 ...         ...           ...
# 45                407               46005          ES      Valencia
# 46                453                 NaN          ES           NaN
# 47                457                 NaN          ES      Valencia
# 48                487               46005          ES      Valencia
# 49                453                 NaN          ES           NaN
#
#           location.state location.country  \
# 0   Comunidad Valenciana           España
# 1   Comunidad Valenciana           España
# 2   Comunidad Valenciana           España
# 3   Comunidad Valenciana           España
# 4   Comunidad Valenciana           España
# ..                   ...              ...
# 45  Comunidad Valenciana           España
# 46                   NaN           España
# 47  Comunidad Valenciana           España
# 48  Comunidad Valenciana           España
# 49                   NaN           España
#
#                             location.formattedAddress location.neighborhood  \
# 0   [Av. Regne de Valencia 9 (Carrer Gregorio Maya...                   NaN
# 1   [Don Juan de Austria 11 (Dr. Romagosa), 46002 ...                   NaN
# 2   [C/ Conde Altea, 5, 46005 Valencia Comunidad V...                   NaN
# 3   [Calle General San Martin 2, Valencia Comunida...                   NaN
# 4   [Martinez Cubells, 10, 46002 Valencia Comunida...                   NaN
# ..                                                ...                   ...
# 45  [Plaça de Cánovas del Castillo (12), 46005 Val...                   NaN
# 46                                           [España]                   NaN
# 47  [Ciscar 24, Valencia Comunidad Valenciana, Esp...                   NaN
# 48  [Carrer de Ciscar 25 (Conde de altea), 46005 V...                   NaN
# 49                                           [España]                   NaN
#
#    venuePage.id
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
#
# [50 rows x 19 columns]

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
filtered_columns = ['name', 'categories', 'location.lat', 'location.lng']
PDR_venues =PDR_venues.loc[:, filtered_columns]

# filter the category for each row
PDR_venues['categories'] = PDR_venues.apply(get_category_type, axis=1)

# clean columns, not required here
#PDR_venues.columns = [col.split(".")[-1] for col in PDR_venues.columns]

PDR_venues.head()
# Out:
#                      name          categories  location.lat  location.lng
# 0   Bar Ché Taberna vasca  Spanish Restaurant     39.464686     -0.372123
# 1          Bar Casa Mundo    Tapas Restaurant     39.470394     -0.372505
# 2  Sportium en Bar Inglés        Betting Shop     39.465335     -0.369937
# 3                Bar Sena                 Bar     39.465434     -0.375904
# 4                Bar Rubi                None     39.468003     -0.373080

# %%
#Update long and lat column titles
PDR_venues.rename(columns={'location.lat': 'latitude', 'location.lng': 'longitude'}, inplace=True)
PDR_venues
# Out:
#                           name          categories   latitude  longitude
# 0        Bar Ché Taberna vasca  Spanish Restaurant  39.464686  -0.372123
# 1               Bar Casa Mundo    Tapas Restaurant  39.470394  -0.372505
# 2       Sportium en Bar Inglés        Betting Shop  39.465335  -0.369937
# 3                     Bar Sena                 Bar  39.465434  -0.375904
# 4                     Bar Rubi                None  39.468003  -0.373080
# ..                         ...                 ...        ...        ...
# 45  El Timbre - Bar y Parrilla                 Bar  39.468749  -0.365919
# 46           MALUKO Coffee Bar         Snack Place  39.468446  -0.375809
# 47        Tributo - Brasas Bar          Restaurant  39.466022  -0.365903
# 48                   Lowen Bar                 Pub  39.466104  -0.365457
# 49                   Resto Bar                Food  39.468483  -0.375808
#
# [50 rows x 4 columns]

# %%
print('{} venues were returned by Foursquare.'.format(PDR_venues.shape[0]))
# Out:
# 50 venues were returned by Foursquare.

# %%
print('There are {} uniques categories.'.format(len(PDR_venues['categories'].unique())))
# Out:
# There are 27 uniques categories.

# %%
#reupdate the central map coordinates
address = 'Pla de Remei, ES'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 39.4680141 -0.3705643

# %%
PDR_map = folium.Map(location=[latitude, longitude], zoom_start=16)
# add a red circle marker to represent central point of Pla de Remei
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='CENTRE',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(PDR_map)
# add all venues as blue circle markers
for lat, lng, label in zip(PDR_venues.latitude, PDR_venues.longitude, PDR_venues.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(PDR_map)
    
PDR_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_d44d0a3939a642fd80ce8d08e4623d47%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d44d0a3939a642fd80ce8d08e4623d47%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d44d0a3939a642fd80ce8d08e4623d47%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_d44d0a3939a642fd80ce8d08e4623d47%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B39.4680141%2C-0.3705643%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2016%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20 ...
